# %%
import sys
sys.path.append("../src")

# Baseline Models with train_test_split and cross-validation
# Wonder how this would change with mutation data???

# You have to pick one drug since response variable (AUC/IC50) is drug-specific 
# Can add nuance behind which drug is picked, that could be cool

from baseline1 import run_baseline_models
from baseline2 import run_baseline_models_cv
from baseline3 import upd_run_baseline_models_cv

# %%
results, drug_df, gene_cols = run_baseline_models(df, "Erlotinib", "LN_IC50")

# Print nicely
for model_name, metrics in results.items():
    print(f"Model: {model_name}")
    for metric_name, value in metrics.items():
        print(f"  {metric_name}: {value:.4f}")
    print()

# %%
results, drug_df, gene_cols = run_baseline_models_cv(df, "Erlotinib", "LN_IC50")

for model_name, metrics in results.items():
    print(f"Model: {model_name}")
    for metric_name, value in metrics.items():
        print(f"  {metric_name}: {value:.4f}")
    print()
    
    # Using gene expression only, baseline models perform poorly (R² ~0)

# %%
results, drug_df, gene_cols = upd_run_baseline_models_cv(df, "Erlotinib", "LN_IC50")

for model_name, metrics in results.items():
    print(f"Model: {model_name}")
    for metric_name, value in metrics.items():
        print(f"  {metric_name}: {value:.4f}")
    print()
